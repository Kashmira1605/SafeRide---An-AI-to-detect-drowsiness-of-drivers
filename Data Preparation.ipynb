# %%
import os
import shutil
import glob
from tqdm import tqdm

# %%
print("Jay Ganesh")
# Out:
# Jay Ganesh

# %% [markdown]
# subject ID:
# xxx
#
# image number:
# xxx
#
# gender:
# 0 - male
# 1 - famale
#
# glasses:
# 0 - no
# 1 - yes
#
# eye state:
# 0 - close
# 1 - open
#
# reflections:
# 0 - none
# 1 - low
# 2 - high
#
# lighting conditions/image quality:
# 0 - bad
# 1 - good
#
# sensor type:
# 01 - RealSense SR300 640x480
# 02 - IDS Imaging, 1280x1024
# 03 - Aptina Imagin 752x480
#
# example:
# s001_00123_0_0_0_0_0_01.png

# %%
raw_dir = r'C:\Users\Manas\Dataset\mrlEyes_2018_01'
closed_eyes_dir = r'C:\Users\Manas\Dataset\Closed_Eyes'
open_eyes_dir =r'C:\Users\Manas\Dataset\Open_Eyes'
for dir_path,dir_name,file_names in os.walk(raw_dir):
    for i in tqdm([f for f in file_names if f.endswith('.png')]):
        if i.split('_')[4] == '0':
            shutil.copy(src=dir_path+'/'+i,dst=closed_eyes_dir)
        elif i.split('_')[4] == '1':
            shutil.copy(src=dir_path+'/'+i,dst=open_eyes_dir)
        #print(i)
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [09:55<00:00, 17.23it/s]
