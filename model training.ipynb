# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import scipy

# %%
tf.test.is_gpu_available()
# Out:
# False

# %%
batch_size = 8

# %%
train_data_generator = ImageDataGenerator(
                                          rescale=1./255,
                                          rotation_range = 0.2 , shear_range = 0.0 , 
                                          zoom_range = 0.0 , width_shift_range = 0.2 , 
                                          height_shift_range = 0.2 ,validation_split =0.2 
                                         )

# %% [markdown]
# Train Data

# %%
train_data = train_data_generator.flow_from_directory(r'C:\Users\Manas\Dataset\train',
                                                      target_size = (80,80),
                                                      batch_size = batch_size,
                                                      class_mode = 'categorical',
                                                      subset = 'training'
                                                     )
validation_data = train_data_generator.flow_from_directory(r'C:\Users\Manas\Dataset\train',
                                                      target_size = (80,80),
                                                      batch_size = batch_size,
                                                      class_mode = 'categorical',
                                                      subset = 'validation'
                                                     )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-c0bded01cdf3> in <cell line: 1>()
# ----> 1 train_data = train_data_generator.flow_from_directory(r'C:\Users\Manas\Dataset\train',
#       2                                                       target_size = (80,80),
#       3                                                       batch_size = batch_size,
#       4                                                       class_mode = 'categorical',
#       5                                                       subset = 'training'
#
# /usr/local/lib/python3.9/dist-packages/keras/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
# ...

# %% [markdown]
# test data

# %%
test_data_generator = ImageDataGenerator(rescale = 1./255 )
test_data = test_data_generator.flow_from_directory(r'C:\Users\Manas\Dataset\test',
                                                      target_size = (80,80),
                                                      batch_size = batch_size,
                                                      class_mode = 'categorical',
                                                     )

# %%
base_model = InceptionV3(
                            include_top = False ,
                            weights = 'imagenet',
                            input_tensor = Input( shape=(80,80,3) )
                        )

# %%
base_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 39, 39, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 39, 39, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 39, 39, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 37, 37, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 37, 37, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 37, 37, 64)   18432       ['activation_1[0][0]']
#
# ...

# %%
head_model = base_model.output
head_model = Flatten()(head_model)
head_model = Dense(64 , activation= 'relu' )(head_model)
head_model = Dropout(0.5)(head_model)
head_model = Dense(2 , activation= 'softmax')(head_model)

#final model
model = Model(inputs = base_model.input , outputs = head_model)
for layer in base_model.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 80, 80, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 39, 39, 32)   864         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 39, 39, 32)  96          ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 39, 39, 32)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 37, 37, 32)   9216        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 37, 37, 32)  96          ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 37, 37, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 37, 37, 64)   18432       ['activation_1[0][0]']
#
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(
                                r'C:\Users\Manas\Dataset\model\model.h5',
                                monitor='val_loss',
                                save_best_only= True,
                                verbose = 3 
                            )

earlystop = EarlyStopping(monitor='val_loss' ,patience = 5 , 
                          verbose= 3 , restore_best_weights= True
                         )

learning_rate = ReduceLROnPlateau(monitor='val_loss',patience=3,verbose=3)

callbacks = [checkpoint ,earlystop,learning_rate]

# %%
model.compile(
              optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy']
             )
model.fit_generator(train_data,
                    steps_per_epoch= train_data.samples//batch_size,
                    validation_data= validation_data,
                    validation_steps= validation_data.samples//batch_size,
                    callbacks= callbacks,
                    epochs = 5
                   )
# Out:
# Epoch 1/5
# C:\Users\Manas\AppData\Local\Temp\ipykernel_8140\1268973641.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_data,
# 8089/8089 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9421
# Epoch 1: val_loss improved from inf to 0.18270, saving model to C:\Users\Manas\Dataset\model\model.h5
# 8089/8089 [==============================] - 1290s 159ms/step - loss: 0.1523 - accuracy: 0.9421 - val_loss: 0.1827 - val_accuracy: 0.9245 - lr: 0.0010
# Epoch 2/5
# 2887/8089 [=========>....................] - ETA: 11:24 - loss: 0.1478 - accuracy: 0.9451
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 6>()
#       1 model.compile(
#       2               optimizer='Adam',
# ...

# %%
#Model evaluation
accuracy_of_training , loss_of_training = model.evaluate_generator(train_data)
print("Accuracy of training data  is : ",accuracy_of_training)
print("Loss of training data is : ",loss_of_training)
# Out:
# C:\Users\Manas\AppData\Local\Temp\ipykernel_8140\736761461.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   accuracy_of_training , loss_of_training = model.evaluate_generator(train_data)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 2>()
#       1 #Model evaluation
# ----> 2 accuracy_of_training , loss_of_training = model.evaluate_generator(train_data)
#       3 print("Accuracy of training data  is : ",accuracy_of_training)
#       4 print("Loss of training data is : ",loss_of_training)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:2646, in Model.evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    2638 warnings.warn(
# ...

# %%
accuracy_of_validation , loss_of_validation = model.evaluate_generator(validation_data)
print("Accuracy of validation data is : ",accuracy_of_validation)
print("Loss of validation data is : ",loss_of_validation)

# %%
accuracy_of_test , loss_of_test = model.evaluate_generator(test_data)
print("Accuracy of test data is : ",accuracy_of_test)
print("Loss of test data is : ",loss_of_test)
